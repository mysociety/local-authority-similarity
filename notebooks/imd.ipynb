# %%
# Notebook to produce the distance calculation

from data_common.notebook import *
from data_common.dataset import get_dataset_df

# %%
df = get_dataset_df("composite_uk_imd", "uk_index", "latest", "la_labels.csv")
df
# Out:
#     local-authority-code  la-deprivation-score             label  \
# 0                    DRS                 62.31  1st IMD quintile
# 1                    BFS                 55.49  1st IMD quintile
# 2                    FMO                 48.63  1st IMD quintile
# 3                    NMD                 48.62  1st IMD quintile
# 4                    CCG                 46.68  1st IMD quintile
# ..                   ...                   ...               ...
# 404                  MSS                  7.74  5th IMD quintile
# 405                  WAE                  7.51  5th IMD quintile
# 406                  RUS                  7.20  5th IMD quintile
# 407                  WOK                  5.83  5th IMD quintile
# 408                  HAT                  5.62  5th IMD quintile
#
#                                           desc  high-deprivation  \
# 0     Councils in most deprived quintile (20%)              0.86
# 1     Councils in most deprived quintile (20%)              0.67
# 2     Councils in most deprived quintile (20%)              0.95
# 3     Councils in most deprived quintile (20%)              0.82
# 4     Councils in most deprived quintile (20%)              0.81
# ..                                         ...               ...
# 404  Councils in least deprived quintile (20%)              0.00
# 405  Councils in least deprived quintile (20%)              0.00
# 406  Councils in least deprived quintile (20%)              0.00
# 407  Councils in least deprived quintile (20%)              0.00
# 408  Councils in least deprived quintile (20%)              0.00
#
#      low-deprivation  medium-deprivation  density
# 0               0.00                0.14   120.79
# 1               0.02                0.31  2482.32
# 2               0.00                0.05    40.97
# 3               0.00                0.18   108.01
# 4               0.00                0.19    72.98
# ..               ...                 ...      ...
# 404             0.87                0.13   455.51
# 405             0.93                0.07   366.83
# 406             0.94                0.06   296.86
# 407             0.95                0.05   971.76
# 408             0.97                0.03   453.99
#
# [409 rows x 8 columns]

# %%
label_df = df[["local-authority-code", "label"]]
label_df.to_csv(Path("data", "packages", "imd_distance", "la_labels.csv"), index=False)
label_df.head()
# Out:
#   local-authority-code             label
# 0                  DRS  1st IMD quintile
# 1                  BFS  1st IMD quintile
# 2                  FMO  1st IMD quintile
# 3                  NMD  1st IMD quintile
# 4                  CCG  1st IMD quintile

# %%
desc = df[["label", "desc"]].drop_duplicates()
desc.to_csv(Path("data", "packages", "imd_distance", "label_desc.csv"), index=False)
desc.head()
# Out:
#                 label                                              desc
# 0    1st IMD quintile          Councils in most deprived quintile (20%)
# 61   2nd IMD quintile   Councils in second most deprived quintile (20%)
# 121  3rd IMD quintile     Councils in middle deprivation quintile (20%)
# 209  4th IMD quintile  Councils in second least deprived quintile (20%)
# 302  5th IMD quintile         Councils in least deprived quintile (20%)

# %%
df
# Out:
#     local-authority-code  la-deprivation-score             label  \
# 0                    DRS                 62.31  1st IMD quintile
# 1                    BFS                 55.49  1st IMD quintile
# 2                    FMO                 48.63  1st IMD quintile
# 3                    NMD                 48.62  1st IMD quintile
# 4                    CCG                 46.68  1st IMD quintile
# ..                   ...                   ...               ...
# 404                  MSS                  7.74  5th IMD quintile
# 405                  WAE                  7.51  5th IMD quintile
# 406                  RUS                  7.20  5th IMD quintile
# 407                  WOK                  5.83  5th IMD quintile
# 408                  HAT                  5.62  5th IMD quintile
#
#                                           desc  high-deprivation  \
# 0     Councils in most deprived quintile (20%)              0.86
# 1     Councils in most deprived quintile (20%)              0.67
# 2     Councils in most deprived quintile (20%)              0.95
# 3     Councils in most deprived quintile (20%)              0.82
# 4     Councils in most deprived quintile (20%)              0.81
# ..                                         ...               ...
# 404  Councils in least deprived quintile (20%)              0.00
# 405  Councils in least deprived quintile (20%)              0.00
# 406  Councils in least deprived quintile (20%)              0.00
# 407  Councils in least deprived quintile (20%)              0.00
# 408  Councils in least deprived quintile (20%)              0.00
#
#      low-deprivation  medium-deprivation  density
# 0               0.00                0.14   120.79
# 1               0.02                0.31  2482.32
# 2               0.00                0.05    40.97
# 3               0.00                0.18   108.01
# 4               0.00                0.19    72.98
# ..               ...                 ...      ...
# 404             0.87                0.13   455.51
# 405             0.93                0.07   366.83
# 406             0.94                0.06   296.86
# 407             0.95                0.05   971.76
# 408             0.97                0.03   453.99
#
# [409 rows x 8 columns]

# %%
d = (
    df.drop(columns=["label", "desc", "la-deprivation-score"])
    .set_index("local-authority-code")
    .space.self_distance(normalize=True)
    .space.match_distance()
    .space.local_rankings()
    .sort_values(["local-authority-code_A", "distance"])
)
d.to_csv(Path("data", "packages", "imd_distance", "distance_map.csv"), index=False)
